# %%
# imports ...
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 15, 10
plt.rcParams['font.size'] = 12
plt.rcParams['xtick.color'] = 'red'
plt.rcParams['ytick.color'] = 'red'
# labels
plt.rcParams['axes.labelcolor'] = 'red'
plt.rcParams['axes.labelsize'] = 20
# grid
plt.rcParams['grid.alpha'] = 0.3
plt.rcParams['grid.color'] = 'red'
plt.rcParams['grid.linestyle'] = '--'
plt.rcParams['axes.grid'] = True

# %%
print('Loading train.csv')
scalars_df = pd.read_csv(os.path.join('../logs', 'train.csv'))
print('Done')
# Out:
# Loading train.csv
# Done

# %%
scalars_df.head()
# Out:
#    epoch  step      loss  accuracy  cls_w_mean  cls_w_std  cls_w_min  \
# 0    0.0   1.0  1.106909      0.50   -0.000115   0.017961  -0.031206
# 1    0.0   2.0  1.460168      0.75   -0.000115   0.017960  -0.031248
# 2    0.0   3.0  1.167974      0.75   -0.000115   0.017959  -0.031283
# 3    0.0   4.0  1.249675      0.75   -0.000115   0.017958  -0.031292
# 4    0.0   5.0  1.236976      0.75   -0.000115   0.017957  -0.031308
#
#    cls_w_max  cls_b_mean  cls_b_std  cls_b_min  cls_b_max
# 0   0.031233   -0.006701   0.011705  -0.014249   0.006782
# 1   0.031199   -0.006710   0.011678  -0.014280   0.006739
# 2   0.031226   -0.006719   0.011659  -0.014317   0.006706
# 3   0.031273   -0.006721   0.011656  -0.014358   0.006695
# 4   0.031321   -0.006726   0.011642  -0.014395   0.006670

# %%
# scalars_df

# %%
scalars_df[['loss']].rolling(1000).mean().plot()
plt.show()

# %%
scalars_df[['accuracy']].rolling(100).mean().plot()
plt.show()

# %%
scalars_df[['cls_b_mean']].plot()
plt.show()
